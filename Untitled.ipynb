# %%
import pandas as pd

# %%
import numpy as np

# %%
with open ('top10.cs') as f:
    top = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-f642017c5aca> in <module>
# ----> 1 with open ('top10.cs') as f:
#       2     top = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'top10.cs'

# %%
df= pd.read_csv('top10s.csv', encoding="latin1")

# %%
ls
# Out:
# Untitled.ipynb  top10s.csv

# %%
df.head(5)
# Out:
#    Unnamed: 0                 title      artist        top genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'artist', 'top genre', 'year', 'bpm', 'nrgy',
#        'dnce', 'dB', 'live', 'val', 'dur', 'acous', 'spch', 'pop'],
#       dtype='object')

# %%
df.sort_values(by=['artist', 'top genre'])
df.sort_values(by='artist', ascending=True)
# Out:
#      Unnamed: 0                               title               artist  \
# 31           32         My First Kiss - feat. Ke$ha                3OH!3
# 229         230                She Looks So Perfect  5 Seconds of Summer
# 249         250                       Say Something    A Great Big World
# 21           22                Whataya Want from Me         Adam Lambert
# 37           38                        If I Had You         Adam Lambert
# ..          ...                                 ...                  ...
# 427         428                         True Colors                 Zedd
# 487         488           Get Low (with Liam Payne)                 Zedd
# 132         133  We Are Young (feat. Janelle Monáe)                 fun.
# 122         123                         Some Nights                 fun.
# 173         174                          #thatPOWER            will.i.am
#
#           top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# ...
